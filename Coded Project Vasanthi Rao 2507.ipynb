# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import copy

# %%
import pandas as pd

# %%
AutomobilesInNewYork=pd.read_excel('D:/Ment Class/Graded Project/AutomobilesInNewYork.xlsx')

# %%
AutomobilesInNewYork.head()
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %%
AutomobilesInNewYork.tail()
# Out:
#       Age Gender Profession Marital_status Education  No_of_Dependents  \
# 1576   22   Male   Salaried         Single  Graduate                 2
# 1577   22   Male   Business        Married  Graduate                 4
# 1578   22   Male   Business         Single  Graduate                 2
# 1579   22   Male   Business        Married  Graduate                 3
# 1580   22   Male   Salaried        Married  Graduate                 4
#
#      Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 1576            No        Yes              No   33300             0.0
# 1577            No         No              No   32000             NaN
# 1578            No        Yes              No   32900             0.0
# 1579           Yes        Yes              No   32200             NaN
# 1580            No         No              No   31600             0.0
#
#       Total_salary  Price       Make
# 1576         33300  27000  Hatchback
# 1577         32000  31000  Hatchback
# ...

# %%
AutomobilesInNewYork.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.1+ KB

# %%
import pandas as pd

# %%
type(AutomobilesInNewYork)
# Out:
# pandas.core.frame.DataFrame

# %%
AutomobilesInNewYork.size
# Out:
# 22134

# %%
print("no. of rows: ",AutomobilesInNewYork.shape[0], "\n""no. of columns: ",AutomobilesInNewYork.shape[1])
# Out:
# no. of rows:  1581
# no. of columns:  14

# %%
list(AutomobilesInNewYork)
# Out:
# ['Age',
#  'Gender',
#  'Profession',
#  'Marital_status',
#  'Education',
#  'No_of_Dependents',
#  'Personal_loan',
#  'House_loan',
#  'Partner_working',
#  'Salary',
#  'Partner_salary',
#  'Total_salary',
#  'Price',
#  'Make']

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.histplot(data=AutomobilesInNewYork, x='Make', kde=True);

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.barplot(data=AutomobilesInNewYork, x='Make', y='Price') ;

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.lineplot(data =AutomobilesInNewYork  , x = 'Marital_status' , y = 'No_of_Dependents');

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.lineplot(data=AutomobilesInNewYork,x = 'Age' , y = 'Gender', ci = False ,hue='Profession');
# Out:
# C:\Users\vasan\AppData\Local\Temp\ipykernel_2348\3424736857.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data=AutomobilesInNewYork,x = 'Age' , y = 'Gender', ci = False ,hue='Profession');

# %%
AutomobilesInNewYork.head()
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %%
AutomobilesInNewYork.shape
# Out:
# (1581, 14)

# %%
AutomobilesInNewYork.index.values
# Out:
# array([   0,    1,    2, ..., 1578, 1579, 1580], dtype=int64)

# %%
AutomobilesInNewYork.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.1+ KB

# %%
AutomobilesInNewYork['Gender'].unique()
# Out:
# array(['Male', 'Femal', 'Female', nan, 'Femle'], dtype=object)

# %%
AutomobilesInNewYork.isnull().any()
# Out:
# Age                 False
# Gender               True
# Profession          False
# Marital_status      False
# Education           False
# No_of_Dependents    False
# Personal_loan       False
# House_loan          False
# Partner_working     False
# Salary              False
# Partner_salary       True
# Total_salary        False
# Price               False
# Make                False
# dtype: bool

# %%
AutomobilesInNewYork['Partner_salary'].unique()
# Out:
# array([70700., 70300., 60700., 60200., 60500., 50800., 40400.,     0.,
#        70600., 60600., 60300., 45500., 40200., 40700.,   600.,   700.,
#        27800., 70000., 40100., 40900., 27000.,    nan, 40500., 50400.,
#        80400., 60900., 60100., 70200., 30000., 40300., 40800., 70800.,
#          900., 45000., 40600., 50700., 80500., 27700., 35800., 26600.,
#        60000., 27900., 60800., 40000., 70100., 38100., 38200., 30200.,
#        38500., 50900., 35100., 38700., 38300., 38900., 23200., 24700.,
#        30800., 28100., 38400., 38000., 23100., 30100., 25700., 70400.,
#          200., 30900., 26100., 45700.,   400., 28200., 70900., 38800.,
#        45200., 26800., 60400., 30300., 25800.,   800., 38600., 24500.,
#        30700., 28500., 24900., 70500., 35900., 30500., 28900., 27200.,
#        45900., 25300., 35600., 25000., 25200., 26300., 35700., 23800.,
#        32700., 30600., 45600., 28000., 32600., 28600., 25100., 26700.,
# ...

# %%
AutomobilesInNewYork[AutomobilesInNewYork['Age'] < 30]
# Out:
#       Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 740    29   Male   Business        Married  Post Graduate                 2
# 741    29   Male   Business        Married  Post Graduate                 3
# 742    29   Male   Business        Married  Post Graduate                 2
# 743    29   Male   Salaried        Married  Post Graduate                 3
# 744    29   Male   Salaried        Married  Post Graduate                 4
# ...   ...    ...        ...            ...            ...               ...
# 1576   22   Male   Salaried         Single       Graduate                 2
# 1577   22   Male   Business        Married       Graduate                 4
# 1578   22   Male   Business         Single       Graduate                 2
# 1579   22   Male   Business        Married       Graduate                 3
# 1580   22   Male   Salaried        Married       Graduate                 4
#
# ...

# %%
AutomobilesInNewYork.isnull().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
AutomobilesInNewYork.Partner_salary=AutomobilesInNewYork.Partner_salary.fillna(AutomobilesInNewYork.Partner_salary.mean())

# %%
AutomobilesInNewYork.isnull().sum()
# Out:
# Age                  0
# Gender              53
# Profession           0
# Marital_status       0
# Education            0
# No_of_Dependents     0
# Personal_loan        0
# House_loan           0
# Partner_working      0
# Salary               0
# Partner_salary       0
# Total_salary         0
# Price                0
# Make                 0
# dtype: int64

# %%
AutomobilesInNewYork['Gender'] = AutomobilesInNewYork['Gender'].fillna(0)

# %%
AutomobilesInNewYork.isnull().sum()
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %%
dups = AutomobilesInNewYork.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 0

# %%
AutomobilesInNewYork[['Salary','Partner_salary']].describe()
# Out:
#              Salary  Partner_salary
# count   1581.000000     1581.000000
# mean   60392.220114    20225.559322
# std    14674.825044    18905.183912
# min    30000.000000        0.000000
# 25%    51900.000000        0.000000
# 50%    59500.000000    24900.000000
# 75%    71800.000000    38000.000000
# max    99300.000000    80500.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
fig, axes = plt.subplots(nrows=2,ncols=2)
fig.set_size_inches(10,8)
sns.histplot(AutomobilesInNewYork['Salary'], kde=True, ax=axes[0][0])
sns.boxplot(x='Salary', data=AutomobilesInNewYork, ax=axes[0][1])
sns.histplot(AutomobilesInNewYork['Partner_salary'] , kde=True, ax=axes[1][0])
sns.boxplot(x='Partner_salary', data=AutomobilesInNewYork , ax=axes[1][1])
plt.show()

# %%
AutomobilesInNewYork['Make'].value_counts(normalize=True)
# Out:
# Sedan        0.444023
# Hatchback    0.368121
# SUV          0.187856
# Name: Make, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.countplot(x='Make', data=AutomobilesInNewYork, palette='pastel',hue = 'Profession')
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
plt.scatter(AutomobilesInNewYork['Salary'],AutomobilesInNewYork['Partner_salary'])

# %%
plt.scatter(AutomobilesInNewYork['Total_salary'],AutomobilesInNewYork['Price'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.countplot(x='Gender', hue='Profession', data=AutomobilesInNewYork)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
import pandas as pd

# %%
pd.crosstab(AutomobilesInNewYork['Gender'],AutomobilesInNewYork['Profession'],margins=True,normalize=True)
# Out:
# Profession  Business  Salaried       All
# Gender
# 0           0.013283  0.020240  0.033523
# Femal       0.000000  0.000633  0.000633
# Female      0.065781  0.141050  0.206831
# Femle       0.000633  0.000000  0.000633
# Male        0.353574  0.404807  0.758381
# All         0.433270  0.566730  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.countplot(x='Education', hue='Personal_loan', data=AutomobilesInNewYork)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
pd.crosstab(AutomobilesInNewYork['Education'],AutomobilesInNewYork['Personal_loan'], margins=True, normalize = True)
# Out:
# Personal_loan        No       Yes       All
# Education
# Graduate       0.182163  0.194813  0.376977
# Post Graduate  0.316888  0.306135  0.623023
# All            0.499051  0.500949  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.countplot(x='Education', hue='House_loan', data=AutomobilesInNewYork)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.countplot(x='Make', hue='Profession', data=AutomobilesInNewYork)
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %%
import pandas as pd

# %%
pd.crosstab(AutomobilesInNewYork['Gender'],AutomobilesInNewYork['Make'], margins=True, normalize = True)
# Out:
# Make    Hatchback       SUV     Sedan       All
# Gender
# 0        0.001265  0.003795  0.028463  0.033523
# Femal    0.000000  0.000633  0.000000  0.000633
# Female   0.009488  0.108159  0.089184  0.206831
# Femle    0.000000  0.000633  0.000000  0.000633
# Male     0.357369  0.074636  0.326376  0.758381
# All      0.368121  0.187856  0.444023  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
fig_dims = (12, 5)
sns.boxplot(x='Make', y='Price', data=AutomobilesInNewYork)
# Out:
# <Axes: xlabel='Make', ylabel='Price'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.pairplot(AutomobilesInNewYork)

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(AutomobilesInNewYork.corr(),annot=True,fmt=".2f");
# Out:
# C:\Users\vasan\AppData\Local\Temp\ipykernel_2348\1085806172.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(AutomobilesInNewYork.corr(),annot=True,fmt=".2f");

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.barplot(data=AutomobilesInNewYork,x='Partner_working',y='Salary',hue = 'Profession')
# Out:
# <Axes: xlabel='Partner_working', ylabel='Salary'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.lineplot(data=AutomobilesInNewYork,x='Make',y='Price',hue = 'Partner_working')
# Out:
# <Axes: xlabel='Make', ylabel='Price'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.scatterplot(data=AutomobilesInNewYork,x='Price',y='Make')
# Out:
# <Axes: xlabel='Price', ylabel='Make'>

# %%
AutomobilesInNewYork.drop(labels='Profession',axis=1,inplace=True)
AutomobilesInNewYork.head()
# Out:
#    Age  Gender Marital_status      Education  No_of_Dependents Personal_loan  \
# 0   53    Male        Married  Post Graduate                 4            No
# 1   53   Femal        Married  Post Graduate                 4           Yes
# 2   53  Female        Married  Post Graduate                 3            No
# 3   53  Female        Married       Graduate                 2           Yes
# 4   53    Male        Married  Post Graduate                 3            No
#
#   House_loan Partner_working  Salary  Partner_salary  Total_salary  Price Make
# 0         No             Yes   99300         70700.0        170000  61000  SUV
# 1         No             Yes   95500         70300.0        165800  61000  SUV
# 2         No             Yes   97300         60700.0        158000  57000  SUV
# 3         No             Yes   72500         70300.0        142800  61000  SUV
# 4         No             Yes   79700         60200.0        139900  57000  SUV

# %%
cat=[]
num=[]
for i in AutomobilesInNewYork.columns:
    if AutomobilesInNewYork[i].dtype=="object":
        cat.append(i)
    else:
        num.append(i)
print(cat) 
print(num)
# Out:
# ['Gender', 'Marital_status', 'Education', 'Personal_loan', 'House_loan', 'Partner_working', 'Make']
# ['Age', 'No_of_Dependents', 'Salary', 'Partner_salary', 'Total_salary', 'Price']

# %%
from scipy.stats import zscore

# %%
data_scaled=AutomobilesInNewYork[num].apply(zscore)
data_scaled.head()
# Out:
#         Age  No_of_Dependents    Salary  Partner_salary  Total_salary  \
# 0  2.502317          1.634953  2.652167        2.670718      3.538836
# 1  2.502317          1.634953  2.393138        2.649553      3.374374
# 2  2.502317          0.574715  2.515836        2.141595      3.068944
# 3  2.502317         -0.485523  0.825333        2.649553      2.473747
# 4  2.502317          0.574715  1.316124        2.115139      2.360190
#
#       Price
# 0  1.863796
# 1  1.863796
# 2  1.570311
# 3  1.863796
# 4  1.570311

# %%
AutomobilesInNewYork.describe()
# Out:
#                Age  No_of_Dependents        Salary  Partner_salary  \
# count  1581.000000       1581.000000   1581.000000     1581.000000
# mean     31.922201          2.457938  60392.220114    20225.559322
# std       8.425978          0.943483  14674.825044    18905.183912
# min      22.000000          0.000000  30000.000000        0.000000
# 25%      25.000000          2.000000  51900.000000        0.000000
# 50%      29.000000          2.000000  59500.000000    24900.000000
# 75%      38.000000          3.000000  71800.000000    38000.000000
# max      54.000000          4.000000  99300.000000    80500.000000
#
#         Total_salary         Price
# count    1581.000000   1581.000000
# mean    79625.996205  35597.722960
# std     25545.857768  13633.636545
# min     30000.000000  18000.000000
# 25%     60500.000000  25000.000000
# 50%     78000.000000  31000.000000
# 75%     95900.000000  47000.000000
# max    171000.000000  70000.000000

# %%
data_scaled.describe()
# Out:
#                Age  No_of_Dependents        Salary  Partner_salary  \
# count  1581.000000      1.581000e+03  1.581000e+03    1.581000e+03
# mean      0.000000     -5.393114e-17 -2.157245e-16    1.438164e-16
# std       1.000316      1.000316e+00  1.000316e+00    1.000316e+00
# min      -1.177945     -2.605999e+00 -2.071700e+00   -1.070180e+00
# 25%      -0.821791     -4.855233e-01 -5.788762e-01   -1.070180e+00
# 50%      -0.346918     -4.855233e-01 -6.081861e-02    2.473353e-01
# 75%       0.721545      5.747147e-01  7.776167e-01    9.404862e-01
# max       2.621035      1.634953e+00  2.652167e+00    3.189258e+00
#
#        Total_salary         Price
# count  1.581000e+03  1.581000e+03
# mean  -3.595409e-17 -1.438164e-16
# std    1.000316e+00  1.000316e+00
# min   -1.943239e+00 -1.291166e+00
# 25%   -7.489296e-01 -7.775678e-01
# 50%   -6.367023e-02 -3.373405e-01
# 75%    6.372522e-01  8.365989e-01
# max    3.577994e+00  2.524137e+00

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)
fig.set_size_inches(10,5)
sns.histplot(AutomobilesInNewYork['Price'] ,kde=True, ax=axes[0])
sns.histplot(data_scaled['Total_salary'] , kde=True, ax=axes[1])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(AutomobilesInNewYork[num])
data_standard=scaler.transform(AutomobilesInNewYork[num])
data_standard=pd.DataFrame(data_standard, columns=AutomobilesInNewYork[num].columns)
data_standard.describe()
# Out:
#                Age  No_of_Dependents        Salary  Partner_salary  \
# count  1581.000000      1.581000e+03  1.581000e+03    1.581000e+03
# mean      0.000000     -5.393114e-17 -2.157245e-16    1.438164e-16
# std       1.000316      1.000316e+00  1.000316e+00    1.000316e+00
# min      -1.177945     -2.605999e+00 -2.071700e+00   -1.070180e+00
# 25%      -0.821791     -4.855233e-01 -5.788762e-01   -1.070180e+00
# 50%      -0.346918     -4.855233e-01 -6.081861e-02    2.473353e-01
# 75%       0.721545      5.747147e-01  7.776167e-01    9.404862e-01
# max       2.621035      1.634953e+00  2.652167e+00    3.189258e+00
#
#        Total_salary         Price
# count  1.581000e+03  1.581000e+03
# mean  -3.595409e-17 -1.438164e-16
# std    1.000316e+00  1.000316e+00
# min   -1.943239e+00 -1.291166e+00
# 25%   -7.489296e-01 -7.775678e-01
# 50%   -6.367023e-02 -3.373405e-01
# 75%    6.372522e-01  8.365989e-01
# max    3.577994e+00  2.524137e+00

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
sns.countplot(x='Make', data=AutomobilesInNewYork, palette='pastel',hue = 'Gender')
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
AutomobilesInNewYork['Make'].value_counts(normalize=True)
# Out:
# Sedan        0.444023
# Hatchback    0.368121
# SUV          0.187856
# Name: Make, dtype: float64

# %%
print(AutomobilesInNewYork.columns)
# Out:
# Index(['Age', 'Gender', 'Marital_status', 'Education', 'No_of_Dependents',
#        'Personal_loan', 'House_loan', 'Partner_working', 'Salary',
#        'Partner_salary', 'Total_salary', 'Price', 'Make'],
#       dtype='object')

# %%
data = {
    'Make': ['SUV','Sedan','Hatchback'],
     'Profession':['Business','Salaried'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Total_salary': [10000,20000,30000,40000,50000,60000,70000,80000,90000,100000,110000,120000,130000,140000,150000,160000,170000,180000,190000,200000] }

# %%
sns.countplot(x='Make', data=AutomobilesInNewYork, palette='pastel',hue = 'Profession')
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = {
    'Make': ['SUV','Sedan','Hatchback'],
     'Profession':['Business','Salaried'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Total_salary': [10000,20000,30000,40000,50000,60000,70000,80000,90000,100000,110000,120000,130000,140000,150000,160000,170000,180000,190000,200000] }

# %%
AutomobilesInNewYork=pd.read_excel('D:/Ment Class/Graded Project/AutomobilesInNewYork.xlsx')

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=AutomobilesInNewYork, x='Make', y='Profession', hue='Gender')
# Out:
# <Axes: xlabel='Make', ylabel='Profession'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.barplot(data=AutomobilesInNewYork,x='Gender',y='Price')
# Out:
# <Axes: xlabel='Gender', ylabel='Price'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.barplot(data=AutomobilesInNewYork,x='Personal_loan',y='Price')
# Out:
# <Axes: xlabel='Personal_loan', ylabel='Price'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.barplot(data=AutomobilesInNewYork,x='Make',y='Price',hue = 'Partner_working')
# Out:
# <Axes: xlabel='Make', ylabel='Price'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.barplot(data=AutomobilesInNewYork, x='Gender', y='Price');

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.barplot(data=AutomobilesInNewYork, x='Marital_status', y='Price');

# %% [markdown]
# Analyze the dataset and list down the top 5 important variables, along with the business justifications.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import copy

# %%
import pandas as pd

# %%
path = ('D:/Ment Class/Graded Project/GoDigitalData.xlsx')
xl = pd.ExcelFile('D:/Ment Class/Graded Project/GoDigitalData.xlsx')
print(xl.sheet_names)
# Out:
# ['Sheet1', 'Sheet3']

# %%
GoDigitalData = xl.parse('Sheet1')

# %%
GoDigitalData.shape
# Out:
# (8448, 28)

# %%
GoDigitalData.isnull().sum()
# Out:
# userid                      0
# card_no                     0
# card_bin_no                 0
# Issuer                      0
# card_type                   0
# card_source_date            0
# high_networth               0
# active_30                   0
# active_60                   0
# active_90                   0
# cc_active30                 0
# cc_active60                 0
# cc_active90                 0
# hotlist_flag                0
# widget_products             0
# engagement_products         0
# annual_income_at_source     0
# other_bank_cc_holding       0
# bank_vintage                0
# T+1_month_activity          0
# T+2_month_activity          0
# T+3_month_activity          0
# T+6_month_activity          0
# T+12_month_activity         0
# Transactor_revolver        38
# avg_spends_l3m              0
# Occupation_at_source        0
# cc_limit                    0
# dtype: int64

# %%
GoDigitalData['Transactor_revolver']=GoDigitalData['Transactor_revolver'].fillna("NA")

# %%
GoDigitalData.isnull().sum()
# Out:
# userid                     0
# card_no                    0
# card_bin_no                0
# Issuer                     0
# card_type                  0
# card_source_date           0
# high_networth              0
# active_30                  0
# active_60                  0
# active_90                  0
# cc_active30                0
# cc_active60                0
# cc_active90                0
# hotlist_flag               0
# widget_products            0
# engagement_products        0
# annual_income_at_source    0
# other_bank_cc_holding      0
# bank_vintage               0
# T+1_month_activity         0
# T+2_month_activity         0
# T+3_month_activity         0
# T+6_month_activity         0
# T+12_month_activity        0
# Transactor_revolver        0
# avg_spends_l3m             0
# Occupation_at_source       0
# cc_limit                   0
# dtype: int64

# %%
GoDigitalData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8448 entries, 0 to 8447
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   userid                   8448 non-null   int64
#  1   card_no                  8448 non-null   object
#  2   card_bin_no              8448 non-null   int64
#  3   Issuer                   8448 non-null   object
#  4   card_type                8448 non-null   object
#  5   card_source_date         8448 non-null   datetime64[ns]
#  6   high_networth            8448 non-null   object
#  7   active_30                8448 non-null   int64
#  8   active_60                8448 non-null   int64
#  9   active_90                8448 non-null   int64
#  10  cc_active30              8448 non-null   int64
#  11  cc_active60              8448 non-null   int64
#  12  cc_active90              8448 non-null   int64
#  13  hotlist_flag             8448 non-null   object
# ...

# %%
GoDigitalData.head()
# Out:
#    userid              card_no  card_bin_no Issuer   card_type  \
# 0       1  4384 39XX XXXX XXXX       438439   Visa        edge
# 1       2  4377 48XX XXXX XXXX       437748   Visa  prosperity
# 2       3  4377 48XX XXXX XXXX       437748   Visa     rewards
# 3       4  4258 06XX XXXX XXXX       425806   Visa   indianoil
# 4       5  4377 48XX XXXX XXXX       437748   Visa        edge
#
#   card_source_date high_networth  active_30  active_60  active_90  ...  \
# 0       2019-09-29             B          0          1          1  ...
# 1       2002-10-30             A          1          1          1  ...
# 2       2013-10-05             C          0          0          0  ...
# 3       1999-06-01             E          0          1          1  ...
# 4       2006-06-13             B          1          1          1  ...
#
#    bank_vintage  T+1_month_activity  T+2_month_activity T+3_month_activity  \
# 0            27                   0                   0                  0
# ...

# %%
dups = GoDigitalData.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 0

# %%
GoDigitalData[['avg_spends_l3m','cc_limit']].describe()
# Out:
#        avg_spends_l3m       cc_limit
# count     8448.000000    8448.000000
# mean     49527.365530  251706.912879
# std      46244.954836  229114.856385
# min          0.000000       0.000000
# 25%      17110.000000   90000.000000
# 50%      37943.000000  150000.000000
# 75%      66095.750000  350000.000000
# max     289292.000000  990000.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import copy

# %%
fig, axes = plt.subplots(nrows=2,ncols=2)
fig.set_size_inches(10,8)
sns.histplot(GoDigitalData['avg_spends_l3m'], kde=True, ax=axes[0][0])
sns.boxplot(x='avg_spends_l3m', data=GoDigitalData, ax=axes[0][1])
sns.histplot(GoDigitalData['cc_limit'] , kde=True, ax=axes[1][0])
sns.boxplot(x='cc_limit', data=GoDigitalData , ax=axes[1][1])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import copy

# %%
sns.countplot(x='Occupation_at_source', data=GoDigitalData, palette='pastel')
# Out:
# <Axes: xlabel='Occupation_at_source', ylabel='count'>

# %%
sns.countplot(x='Issuer', hue='Occupation_at_source', data=GoDigitalData)
# Out:
# <Axes: xlabel='Issuer', ylabel='count'>

# %%
pd.crosstab(GoDigitalData['Issuer'],GoDigitalData['Occupation_at_source'], margins=True, normalize = True)
# Out:
# Occupation_at_source         0  Housewife   Retired  Salaried  Self Employed  \
# Issuer
# Amex                  0.002012   0.002367  0.004853  0.026160       0.012784
# Mastercard            0.003196   0.004143  0.009233  0.038234       0.024503
# Visa                  0.025687   0.038944  0.114820  0.399384       0.220170
# All                   0.030895   0.045455  0.128906  0.463778       0.257457
#
# Occupation_at_source   Student       All
# Issuer
# Amex                  0.004025  0.052202
# Mastercard            0.006866  0.086174
# Visa                  0.062618  0.861624
# All                   0.073509  1.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import copy

# %%
plt.figure(figsize=(15,15))
sns.heatmap(GoDigitalData.corr(),annot=True,fmt=".2f");
# Out:
# C:\Users\vasan\AppData\Local\Temp\ipykernel_2348\2797126617.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(GoDigitalData.corr(),annot=True,fmt=".2f");

# %%
GoDigitalData.drop(labels='userid',axis=1,inplace=True)
GoDigitalData.head()
# Out:
#                card_no  card_bin_no Issuer   card_type card_source_date  \
# 0  4384 39XX XXXX XXXX       438439   Visa        edge       2019-09-29
# 1  4377 48XX XXXX XXXX       437748   Visa  prosperity       2002-10-30
# 2  4377 48XX XXXX XXXX       437748   Visa     rewards       2013-10-05
# 3  4258 06XX XXXX XXXX       425806   Visa   indianoil       1999-06-01
# 4  4377 48XX XXXX XXXX       437748   Visa        edge       2006-06-13
#
#   high_networth  active_30  active_60  active_90  cc_active30  ...  \
# 0             B          0          1          1            0  ...
# 1             A          1          1          1            0  ...
# 2             C          0          0          0            0  ...
# 3             E          0          1          1            1  ...
# 4             B          1          1          1            0  ...
#
#    bank_vintage  T+1_month_activity T+2_month_activity  T+3_month_activity  \
# ...

# %%
GoDigitalData.drop(labels='card_source_date',axis=1,inplace=True)
GoDigitalData.head()
# Out:
#                card_no  card_bin_no Issuer   card_type high_networth  \
# 0  4384 39XX XXXX XXXX       438439   Visa        edge             B
# 1  4377 48XX XXXX XXXX       437748   Visa  prosperity             A
# 2  4377 48XX XXXX XXXX       437748   Visa     rewards             C
# 3  4258 06XX XXXX XXXX       425806   Visa   indianoil             E
# 4  4377 48XX XXXX XXXX       437748   Visa        edge             B
#
#    active_30  active_60  active_90  cc_active30  cc_active60  ...  \
# 0          0          1          1            0            0  ...
# 1          1          1          1            0            0  ...
# 2          0          0          0            0            0  ...
# 3          0          1          1            1            1  ...
# 4          1          1          1            0            1  ...
#
#    bank_vintage T+1_month_activity  T+2_month_activity  T+3_month_activity  \
# ...

# %%
cat=[]
num=[]
for i in GoDigitalData.columns:
    if GoDigitalData[i].dtype=="object":
        cat.append(i)
    else:
        num.append(i)
print(cat) 
print(num)
# Out:
# ['card_no', 'Issuer', 'card_type', 'high_networth', 'hotlist_flag', 'other_bank_cc_holding', 'Transactor_revolver', 'Occupation_at_source']
# ['card_bin_no', 'active_30', 'active_60', 'active_90', 'cc_active30', 'cc_active60', 'cc_active90', 'widget_products', 'engagement_products', 'annual_income_at_source', 'bank_vintage', 'T+1_month_activity', 'T+2_month_activity', 'T+3_month_activity', 'T+6_month_activity', 'T+12_month_activity', 'avg_spends_l3m', 'cc_limit']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler().fit(GoDigitalData[num])
data_minmax = scaler.transform(GoDigitalData[num])
data_minmax=pd.DataFrame(data_minmax, columns=GoDigitalData[num].columns)
data_minmax.describe()
# Out:
#        card_bin_no    active_30    active_60    active_90  cc_active30  \
# count  8448.000000  8448.000000  8448.000000  8448.000000  8448.000000
# mean      0.406290     0.292377     0.494792     0.642045     0.284091
# std       0.207044     0.454881     0.500002     0.479427     0.451007
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.334947     0.000000     0.000000     0.000000     0.000000
# 50%       0.411749     0.000000     0.000000     1.000000     0.000000
# 75%       0.417779     1.000000     1.000000     1.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        cc_active60  cc_active90  widget_products  engagement_products  \
# count  8448.000000  8448.000000      8448.000000          8448.000000
# mean      0.484493     0.632339         0.516369             0.498979
# std       0.499789     0.482197         0.324742             0.321500
# ...

# %%
GoDigitalData[cat]
# Out:
#                   card_no Issuer   card_type high_networth hotlist_flag  \
# 0     4384 39XX XXXX XXXX   Visa        edge             B            N
# 1     4377 48XX XXXX XXXX   Visa  prosperity             A            N
# 2     4377 48XX XXXX XXXX   Visa     rewards             C            N
# 3     4258 06XX XXXX XXXX   Visa   indianoil             E            N
# 4     4377 48XX XXXX XXXX   Visa        edge             B            N
# ...                   ...    ...         ...           ...          ...
# 8443  4262 41XX XXXX XXXX   Visa   chartered             A            N
# 8444    37691 6XXXX XXXXX   Amex   centurion             A            N
# 8445  4375 51XX XXXX XXXX   Visa     rewards             D            N
# 8446  4477 47XX XXXX XXXX   Visa   indianoil             C            N
# 8447  4262 41XX XXXX XXXX   Visa     rewards             D            N
#
#      other_bank_cc_holding Transactor_revolver Occupation_at_source
# ...

# %%
GoDigitalData["Issuer"] =GoDigitalData["Issuer"].astype('category')
GoDigitalData.dtypes
# Out:
# card_no                      object
# card_bin_no                   int64
# Issuer                     category
# card_type                    object
# high_networth                object
# active_30                     int64
# active_60                     int64
# active_90                     int64
# cc_active30                   int64
# cc_active60                   int64
# cc_active90                   int64
# hotlist_flag                 object
# widget_products               int64
# engagement_products           int64
# annual_income_at_source       int64
# other_bank_cc_holding        object
# bank_vintage                  int64
# T+1_month_activity            int64
# T+2_month_activity            int64
# T+3_month_activity            int64
# T+6_month_activity            int64
# T+12_month_activity           int64
# Transactor_revolver          object
# avg_spends_l3m                int64
# Occupation_at_source         object
# cc_limit                      int64
# ...

# %% [markdown]
# Insights:
# Changing the label doesnot effect the card details of average spending.
